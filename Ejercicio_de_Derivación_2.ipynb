# %% [markdown]
# <a href="https://colab.research.google.com/github/Metodoscomputacionales1/Metodos1_PedroAngarita_SimonUribe/blob/main/Ejercicio_de_Derivaci%C3%B3n_2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
from mpl_toolkits.mplot3d import Axes3D
import matplotlib.pyplot as plt
import plotly.express as px

# %%
nodos=np.linspace(-10,10,401
                  )

# %%
def funcion(x:float):
  return 1/((1+1/(np.exp((x**2))))**(1/2))
funcion(-10)
# Out:
# 1.0

# %%
def funcion_derivada_real(x:float):
  return np.exp(-x**2)*x/((1+np.exp(-x**2))**(3/2))
derivadas_reales=[]
for i in nodos:
  derivadas_reales.append(funcion_derivada_real(i))
plt.plot(nodos,derivadas_reales)

# %%
imagenes=[]
for a in nodos:
  imagenes.append(funcion(a))

plt.plot(nodos,imagenes)

# %%
def derivada_central_por_nodo(x:list):
  h=0.05
  derivada=[]
  for i in range(1,len(x)-1):
    derivada.append((x[i+1]-x[i-1])/(2*h))

  return derivada
derivadas_centrales=derivada_central_por_nodo(imagenes)
nodos2=nodos[1:-1]
plt.plot(nodos2,derivadas_centrales)

# %%
#error_local
errror_local=[]
derivadas_reales2=derivadas_reales[1:-1]
for i in range(len(derivadas_reales2)):
  errror_local.append(abs(derivadas_reales2[i]-derivadas_centrales[i]))

# %%
#error promedio
cuenta=0
for i in errror_local:
  cuenta=+i

a=cuenta/len(errror_local)
a
# Out:
# 2.5154213366734747e-45

# %%
plt.plot(nodos2,errror_local)
#
